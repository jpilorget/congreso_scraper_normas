# %%
# -*- coding: utf-8 -*-
import urllib.request
import re
from bs4 import BeautifulSoup
import pickle
import os.path
import json

def gets_html(url):
    """ Lee un url y devuelve el código html """
    req = urllib.request.Request(url,
                                 headers={'User-Agent':
                                          'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'})
    html = urllib.request.urlopen(req).read().decode("utf-8")
    return html

def gets_article_links(html):
    soup = BeautifulSoup(html, "lxml")
    articles = soup.find_all("article", class_="nota")
    links = [article.a['href'] for article in articles]
    links = ['https://www.lanacion.com.ar'+link for link in links]
    return links

def gets_article(html):
    soup = BeautifulSoup(html, "lxml")
    titulo = soup.find_all("h1", class_='titulo')[0].text.strip()
    fecha = soup.find_all("", class_='fecha')[0].text.strip()
    textos = [p.text for p in soup.find_all("p") if len(p.text) > 100]
    texto = ''.join(textos)
    return fecha, titulo, texto

url = 'https://www.lanacion.com.ar/revista-brando-t61735'
def scrap_url(url):
    #Scraps the homepage with links
    html = gets_html(url)
    links = gets_article_links(html)
    articles = {}
    for link in links:
        html = gets_html(link)
        titulo, texto = gets_article(html)
        articles.update({link:[titulo,texto]})
    return articles

#ohlala_url = 'https://api-contenidos.lanacion.com.ar/json/v2/tema/50784?p={}&c={}&s=1'
brando_url = 'https://api-contenidos.lanacion.com.ar/json/v2/tema/61735?p={}&c={}&s=1'
base_url = brando_url

def crawl(file_path, base_url, articles_request=30, calls = 100):
    #crawls the whole web using calls to the API
    
    #base_url: API URL
    #articles_request: how many articles per call
    #calls: how many calls to the API
    #file_path: Path to file were parsed data has been saved or is going to be saved if it doesnt exist
    
    #Load previously saved data if exists
    if os.path.isfile(file_path):
        articles = pickle.load( open( file_path, "rb" ) )
        parsed_urls = list(articles.keys())
    else:
        parsed_urls = []
        articles = {}
        
    i = 0
    for t in range(calls):
        #Get URLs from api
        api_call = base_url.format(3000+t+1,articles_request)
        print('Getting {} call'.format(t+1))
        json_str = gets_html(api_call)
        json_articles = json.loads(json_str).get('items')
        urls = ['https://www.lanacion.com.ar/'+url['url'] for url in json_articles]
        print('URLs retrieved:')
        print(*urls, sep='\n')

        #Filter new urls
        urls = [url for url in urls if url not in parsed_urls]
        print('URLs to parse: {:02d}'.format(len(urls)))
        
        #If after N calls no new URLs are found, exit
        if len(urls) == 0:
            i += 1
            if i == calls:
                print('No more urls to parse')
                return articles
            else:
                print('{:02d} responses with no new URLs'.format(i))
                continue
        #Get htmls from the URL list, parse and save in dictionary
        try:
            htmls = [(url,gets_html(url)) for url in urls]
            parsed_urls.extend(urls)
            p = 0
            for url,html in htmls:
                p += 1
                print('parsing {:02d} URL'.format(p))
                fecha, titulo, texto = gets_article(html)
                articles.update({url:[fecha, titulo, texto]})
            with open(file_path, 'wb') as f:
                # Pickle the 'data' dictionary using the highest protocol available.
                pickle.dump(articles, f, pickle.HIGHEST_PROTOCOL)
        except:
            continue
    return articles

articles = crawl('/home/fer/text_mining/brando.p',base_url, articles_request=2, calls = 50000)
#articles = crawl('/home/fer/text_mining/ohlala.p',base_url, articles_request=2, calls = 10)
# Out:
# Getting 1 call
# URLs retrieved:
# https://www.lanacion.com.ar/1325111-nueva-sony-cybershot-dsc-hx5
# https://www.lanacion.com.ar/1326009-la-c-de-la-gastronomia-afrodisiaca
# URLs to parse: 00
# 01 responses with no new URLs
# Getting 2 call
# URLs retrieved:
# https://www.lanacion.com.ar/1325989-5-cachetazos-y-algo-mas-que-quedaran-en-el-recuerdo
# https://www.lanacion.com.ar/1325087-donde-se-disfrutan-los-mejores-cigarros-de-buenos-aires
# URLs to parse: 00
# 02 responses with no new URLs
# Getting 3 call
# URLs retrieved:
# https://www.lanacion.com.ar/1325722-pablo-fazio-cervecero-por-opcion
# https://www.lanacion.com.ar/1325720-gustavo-fernandez-protomastro-chatarrero-profesional
# URLs to parse: 00
# 03 responses with no new URLs
# Getting 4 call
# URLs retrieved:
# https://www.lanacion.com.ar/1325714-eduardo-costantini-h-el-productor-detras-del-cine-de-autor
# https://www.lanacion.com.ar/1325710-javier-otaegui-el-mago-de-la-computadora
# URLs to parse: 00
# 04 responses with no new URLs
# Getting 5 call
# URLs retrieved:
# https://www.lanacion.com.ar/1325707-juan-martin-lutteral-pasion-por-las-ideas
# https://www.lanacion.com.ar/1325418-10-cosas-que-tenes-que-saber-para-salir-con-jazmin-de-grazia
# URLs to parse: 00
# 05 responses with no new URLs
# Getting 6 call
# URLs retrieved:
# https://www.lanacion.com.ar/1325375-mira-la-nueva-tableta-dell-inspiron-duo
# https://www.lanacion.com.ar/1325138-5-razones-por-las-que-no-vamos-a-recordar-el-ultimo-superclasico
# URLs to parse: 00
# 06 responses with no new URLs
# Getting 7 call
# URLs retrieved:
# https://www.lanacion.com.ar/1324151-el-fin-de-las-oficinas-conoce-los-nuevos-espacios-de-trabajo
# https://www.lanacion.com.ar/1322867-conoces-el-nuevo-renault-fluence
# URLs to parse: 00
# 07 responses with no new URLs
# Getting 8 call
# URLs retrieved:
# https://www.lanacion.com.ar/http://www.lanacion.com.ar/nota.asp?nota_id=1323514
# https://www.lanacion.com.ar/1323500-cuales-son-los-autos-compactos-mas-populares-de-argentina
# URLs to parse: 02
# Getting 9 call
# URLs retrieved:
# https://www.lanacion.com.ar/1323818-granata-vs-vanucci-cual-le-envidias-mas-al-ogro-fabbiani
# https://www.lanacion.com.ar/1323722-cenas-privadas-son-las-de-ahora
# URLs to parse: 00
# 08 responses with no new URLs
# Getting 10 call
# URLs retrieved:
# https://www.lanacion.com.ar/1322869-teclado-solar-logitech-k750
# https://www.lanacion.com.ar/1323409-azafatas-en-bikini-para-bajar-la-ansiedad-en-el-aeropuerto
# URLs to parse: 00
# 09 responses with no new URLs
# Getting 11 call
# URLs retrieved:
# https://www.lanacion.com.ar/1323146-5-cosas-que-podrias-hacer-con-la-plata-de-la-entrada-para-paul-mccartney
# https://www.lanacion.com.ar/http://blogs.lanacion.com.ar/en-foco/el-arte-de-playboy-a-la-venta/
# URLs to parse: 02
# Getting 12 call
# URLs retrieved:
# https://www.lanacion.com.ar/1322894-baile-del-cano-las-bailarinas-mas-calientes-en-buenos-aires
# https://www.lanacion.com.ar/1322874-xbox-vs-playstation-cual-es-tu-consola-de-video-juegos-favorita
# URLs to parse: 00
# 10 responses with no new URLs
# Getting 13 call
# URLs retrieved:
# https://www.lanacion.com.ar/1322032-sexo-y-prosperidad-el-secreto-detras-de-la-riqueza
# https://www.lanacion.com.ar/1321976-donde-comes-la-mejor-comida-peruana
# URLs to parse: 00
# 11 responses with no new URLs
# Getting 14 call
# URLs retrieved:
# https://www.lanacion.com.ar/1319763-nuevo-chevrolet-cruze
# https://www.lanacion.com.ar/1322067-playboy-hizo-su-homenaje-hot-de-volver-al-futuro
# URLs to parse: 00
# 12 responses with no new URLs
# Getting 15 call
# URLs retrieved:
# https://www.lanacion.com.ar/1321989-las-buenas-maneras-se-perdieron
# https://www.lanacion.com.ar/1321640-la-picada-es-enemiga-de-la-cerveza
# URLs to parse: 00
# 13 responses with no new URLs
# Getting 16 call
# URLs retrieved:
# https://www.lanacion.com.ar/1321691-5-modelos-de-zapatillas-inspiradas-en-iconos-retro
# https://www.lanacion.com.ar/http://blogs.lanacion.com.ar/en-foco/el-disneyworld-de-ferrari/
# URLs to parse: 02
# Getting 17 call
# URLs retrieved:
# https://www.lanacion.com.ar/1321322-sabes-cual-es-la-mejor-epoca-del-ano-para-cortar-con-tu-pareja
# https://www.lanacion.com.ar/1321250-asus-eeepc-lamborghini-vx6
# URLs to parse: 00
# 14 responses with no new URLs
# Getting 18 call
# URLs retrieved:
# https://www.lanacion.com.ar/1320942-sabes-que-es-el-sexo-gourmet
# https://www.lanacion.com.ar/1319756-mira-las-nuevas-zapatillas-inspiradas-en-manny-pacquiao
# URLs to parse: 00
# 15 responses with no new URLs
# Getting 19 call
# URLs retrieved:
# https://www.lanacion.com.ar/1320700-flor-torrente-vs-brenda-gandini-cual-es-tu-lolita-preferida
# https://www.lanacion.com.ar/1320688-cuales-son-los-mejores-bodegones-de-buenos-aires
# URLs to parse: 00
# 16 responses with no new URLs
# Getting 20 call
# URLs retrieved:
# https://www.lanacion.com.ar/1320632-numero-59-noviembre-2010
# https://www.lanacion.com.ar/1319433-como-se-hace-un-analisis-de-adn
# URLs to parse: 00
# 17 responses with no new URLs
# Getting 21 call
# URLs retrieved:
# https://www.lanacion.com.ar/1319750-5-propuestas-de-estilo-para-vestir-jean-en-primavera
# https://www.lanacion.com.ar/1318483-conoce-la-nueva-ford-ranger-2011
# URLs to parse: 00
# 18 responses with no new URLs
# Getting 22 call
# URLs retrieved:
# https://www.lanacion.com.ar/1319409-vanina-vs-silvina-con-cual-de-las-dos-hermanas-escudero-te-quedas
# https://www.lanacion.com.ar/1319383-nuestro-kirchner
# URLs to parse: 00
# 19 responses with no new URLs
# Getting 23 call
# URLs retrieved:
# https://www.lanacion.com.ar/1319360-merodeo-sibaritico-por-balcarce-necochea-y-san-cayetano
# https://www.lanacion.com.ar/1318843-donde-comprar-arte-desde-50-pesos-en-buenos-aires
# URLs to parse: 00
# 20 responses with no new URLs
# Getting 24 call
# URLs retrieved:
# https://www.lanacion.com.ar/1317595-10-cosas-que-debemos-saber-sobre-las-mujeres
# https://www.lanacion.com.ar/1318518-los-lectores-y-sus-mejores-bares-para-despues-de-la-oficina
# URLs to parse: 00
# 21 responses with no new URLs
# Getting 25 call
# URLs retrieved:
# https://www.lanacion.com.ar/1318819-la-revolucion-portatil-lo-que-nos-dejo-el-walkman
# https://www.lanacion.com.ar/http://www.conexionbrando.com/consignas/834-Termina%20el%20mes%20y%20te%20sobran%20unos%20mangos%20%
# URLs to parse: 02
# Getting 26 call
# URLs retrieved:
# https://www.lanacion.com.ar/1318502-valeria-mazza-vs-claudia-schiffer-cual-es-tu-rubia-favorita
# https://www.lanacion.com.ar/1317588-cygnet-que-te-parece-el-compacto-de-aston-martin
# URLs to parse: 00
# 22 responses with no new URLs
# Getting 27 call
# URLs retrieved:
# https://www.lanacion.com.ar/1317513-cuales-son-los-mejores-bares-para-un-after-office
# https://www.lanacion.com.ar/1317562-5-tragos-para-disfrutar-la-primavera-al-aire-libre
# URLs to parse: 00
# 23 responses with no new URLs
# Getting 28 call
# URLs retrieved:
# https://www.lanacion.com.ar/1317139-riquelme-vs-ronaldinho-quien-te-parece-que-tira-los-mejores-canos
# https://www.lanacion.com.ar/1317091-london-festival-restaurant-una-experiencia-a-imitar
# URLs to parse: 00
# 24 responses with no new URLs
# Getting 29 call
# URLs retrieved:
# https://www.lanacion.com.ar/1316845-sexcom-se-vendio-el-dominio-mas-caliente-de-la-web
# https://www.lanacion.com.ar/1316757-como-hacer-para-que-facebook-no-afecte-tu-trabajo
# URLs to parse: 00
# 25 responses with no new URLs
# Getting 30 call
# URLs retrieved:
# https://www.lanacion.com.ar/1316751-que-te-parecio-el-nuevo-smartphone-palm-pre2
# https://www.lanacion.com.ar/1316526-5-programas-p2p-que-hicieron-historia
# URLs to parse: 00
# 26 responses with no new URLs
# Getting 31 call
# URLs retrieved:
# https://www.lanacion.com.ar/1316474-conoce-los-modelos-de-autos-que-mas-multas-reciben
# https://www.lanacion.com.ar/1316247-volver-al-futuro-michael-fox-se-convirtio-en-marty-mcfly-de-nuevo
# URLs to parse: 00
# 27 responses with no new URLs
# Getting 32 call
# URLs retrieved:
# https://www.lanacion.com.ar/1316174-kelly-brook-vs-victoria-beckham-cual-es-la-botinera-premium-mas-caliente
# https://www.lanacion.com.ar/1314853-cuales-te-parecen-los-peores-restaurantes-para-una-primera-cita
# URLs to parse: 00
# 28 responses with no new URLs
# Getting 33 call
# URLs retrieved:
# https://www.lanacion.com.ar/1314883-audi-e-tron-spyder
# https://www.lanacion.com.ar/1315276-rainbow-marketing-las-marcas-a-la-caza-del-segmento-gay
# URLs to parse: 00
# 29 responses with no new URLs
# Getting 34 call
# URLs retrieved:
# https://www.lanacion.com.ar/1315224-mira-el-topless-de-la-hija-rebelde-de-mick-jagger
# https://www.lanacion.com.ar/1314855-ufa-otra-exposicion-de-vinos-que-tal-si-se-juntan-de-una-vez
# URLs to parse: 00
# 30 responses with no new URLs
# Getting 35 call
# URLs retrieved:
# https://www.lanacion.com.ar/1314892-toti-pasman-vs-maradona-a-un-ano-del-la-tenes-adentro-quien-tenia-razon
# https://www.lanacion.com.ar/1314888-los-simpsons-por-bansky
# URLs to parse: 00
# 31 responses with no new URLs
# Getting 36 call
# URLs retrieved:
# https://www.lanacion.com.ar/1314882-adidas
# https://www.lanacion.com.ar/1314537-como-pegarte-un-faltazo-en-la-oficina-sin-ser-descubierto-vos-como-haces
# URLs to parse: 00
# 32 responses with no new URLs
# Getting 37 call
# URLs retrieved:
# https://www.lanacion.com.ar/1313078-brando-maps-un-recorrido-por-lo-mejor-de-boedo
# https://www.lanacion.com.ar/1314548-mercedes-oviedo-el-lado-sexy-de-la-chica-inocente
# URLs to parse: 00
# 33 responses with no new URLs
# Getting 38 call
# URLs retrieved:
# https://www.lanacion.com.ar/1314246-las-mejores-etiquetas-argentinas-de-tannat
# https://www.lanacion.com.ar/1314218-windows-phone-7-la-nueva-apuesta-de-microsoft-para-smartphones
# URLs to parse: 00
# 34 responses with no new URLs
# Getting 39 call
# URLs retrieved:
# https://www.lanacion.com.ar/1313056-que-tiene-en-su-ipod-anibal-fernandez
# https://www.lanacion.com.ar/1313007-jagger-vs-richards-con-cual-de-las-dos-hijas-rockeras-te-quedas
# URLs to parse: 00
# 35 responses with no new URLs
# Getting 40 call
# URLs retrieved:
# https://www.lanacion.com.ar/1312960-nuevos-habitos-de-consumo-el-primer-round-para-el-ebook
# https://www.lanacion.com.ar/1312942-salir-a-correr-antes-o-despues-de-ir-a-trabajar-que-preferis
# URLs to parse: 00
# 36 responses with no new URLs
# Getting 41 call
# URLs retrieved:
# https://www.lanacion.com.ar/1312567-el-tenedor-pilar-de-la-civilizacion-occidental
# https://www.lanacion.com.ar/1312262-conoce-la-nintendo-3ds
# URLs to parse: 00
# 37 responses with no new URLs
# Getting 42 call
# URLs retrieved:
# https://www.lanacion.com.ar/1312295-a-quien-elegirias-para-atenderte-en-esta-isla-paradisiaca
# https://www.lanacion.com.ar/1311835-vermus-y-vinos-quinados-todo-sobre-como-tomar-aperitivos
# URLs to parse: 00
# 38 responses with no new URLs
# Getting 43 call
# URLs retrieved:
# https://www.lanacion.com.ar/1312228-top-five-las-modelos-mas-calientes-de-los-90
# https://www.lanacion.com.ar/1311322-cuales-son-las-canciones-que-hacen-llorar-a-los-hombres-argentinos
# URLs to parse: 00
# 39 responses with no new URLs
# Getting 44 call
# URLs retrieved:
# https://www.lanacion.com.ar/1311727-que-dupla-argentina-de-atacantes-deberia-tener-un-cargo-politico
# https://www.lanacion.com.ar/1311288-buenos-aires-photo-2010
# URLs to parse: 00
# 40 responses with no new URLs
# Getting 45 call
# URLs retrieved:
# https://www.lanacion.com.ar/1310283-autoestereos-xplod-de-sony
# https://www.lanacion.com.ar/1311262-katy-perry-vs-taylor-swift-cual-te-parece-que-es-la-estrella-teen-del-momento
# URLs to parse: 00
# 41 responses with no new URLs
# Getting 46 call
# URLs retrieved:
# https://www.lanacion.com.ar/1310233-a-que-suena-tu-marca-el-negocio-del-audiobranding
# https://www.lanacion.com.ar/1310287-una-mirada-al-vestidor-de-sebastian-de-caro
# URLs to parse: 00
# 42 responses with no new URLs
# Getting 47 call
# URLs retrieved:
# https://www.lanacion.com.ar/1310288-gibson-y-lennon
# https://www.lanacion.com.ar/1310285-musica-con-tu-ipad
# URLs to parse: 00
# 43 responses with no new URLs
# Getting 48 call
# URLs retrieved:
# https://www.lanacion.com.ar/1310221-cuatro-chef-que-te-devuelven-el-placer-por-la-cocina
# https://www.lanacion.com.ar/1309812-maradona-vs-grondona-de-que-lado-te-pones
# URLs to parse: 00
# 44 responses with no new URLs
# Getting 49 call
# URLs retrieved:
# https://www.lanacion.com.ar/1309893-la-red-social-5-parodias-imperdibles-sobre-la-pelicula-de-facebook
# https://www.lanacion.com.ar/1309836-perdimos-las-amas-de-casa-y-ahora-los-comedores-de-las-casas
# URLs to parse: 00
# 45 responses with no new URLs
# Getting 50 call
# URLs retrieved:
# https://www.lanacion.com.ar/1309478-mozilla-seabird-conoce-el-futuro-de-los-celulares-y-contanos-que-te-parecio
# https://www.lanacion.com.ar/1309219-cinco-magnates-que-podrian-ocupar-el-lugar-de-gordon-gekko
# URLs to parse: 00
# 46 responses with no new URLs
# Getting 51 call
# URLs retrieved:
# https://www.lanacion.com.ar/1309492-porsche-le-rinde-homenaje-a-la-linea-speedster-con-un-nuevo-911
# https://www.lanacion.com.ar/1309460-macgyver-cumple-25-anos
# URLs to parse: 00
# 47 responses with no new URLs
# Getting 52 call
# URLs retrieved:
# https://www.lanacion.com.ar/1308935-conoce-los-mejores-temas-de-rock-de-la-historia-segun-morrissey
# https://www.lanacion.com.ar/1308895-google-cumple-12-anos-logros-y-desafios-de-la-marca-mas-valiosa-de-la-web
# URLs to parse: 00
# 48 responses with no new URLs
# Getting 53 call
# URLs retrieved:
# https://www.lanacion.com.ar/1303324-chery-qq
# https://www.lanacion.com.ar/1308926-numero-58-octubre-2010
# URLs to parse: 00
# 49 responses with no new URLs
# Getting 54 call
# URLs retrieved:
# https://www.lanacion.com.ar/1308871-lindsay-lohan-vs-paris-hilton-cual-es-la-estrella-mas-fiestera
# https://www.lanacion.com.ar/1307966-iphone4-en-argentina-te-los-comprarias
# URLs to parse: 00
# 50 responses with no new URLs
# Getting 55 call
# URLs retrieved:
# https://www.lanacion.com.ar/1307927-gustavo-santaolalla-productor-de-vinos
# https://www.lanacion.com.ar/1307517-ipad-vs-galaxy-tab-cual-de-la-dos-elegirias-como-tu-tablet-pc
# URLs to parse: 00
# 51 responses with no new URLs
# Getting 56 call
# URLs retrieved:
# https://www.lanacion.com.ar/1307569-5-sitios-para-encontrar-los-mejores-links-de-internet
# https://www.lanacion.com.ar/1307531-el-ab-de-la-gastronomia-afrodisiaca
# URLs to parse: 00
# 52 responses with no new URLs
# Getting 57 call
# URLs retrieved:
# https://www.lanacion.com.ar/1307248-top-five-iconos-sexuales-geek
# https://www.lanacion.com.ar/1307212-mira-el-nuevo-bmw-compatible-con-ipod-y-ipad
# URLs to parse: 00
# 53 responses with no new URLs
# Getting 58 call
# URLs retrieved:
# https://www.lanacion.com.ar/1306914-5-restaurantes-para-probar-la-mejor-comida-china-agrega-tu-favorito
# https://www.lanacion.com.ar/1306602-jaguar-cumple-75-anos-imponiendo-su-estilo
# URLs to parse: 00
# 54 responses with no new URLs
# Getting 59 call
# URLs retrieved:
# https://www.lanacion.com.ar/1306538-sharon-stone-vs-demi-moore-con-cual-de-los-dos-sex-symbols-de-los-90-te-quedas
# https://www.lanacion.com.ar/1303315-samsung-hmx-t10
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 60 call
# URLs retrieved:
# https://www.lanacion.com.ar/1305675-ciclismo-urbano-por-que-la-bicicleta-es-el-mejor-transporte-para-la-ciudad-de-buenos-aires
# https://www.lanacion.com.ar/1305277-sabes-cual-es-la-marca-mas-valiosa-del-mundo-entra-y-averigualo
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 61 call
# URLs retrieved:
# https://www.lanacion.com.ar/1304889-david-nalbandian-vs-gal-monfils-quien-te-parece-que-sera-el-heroe-de-la-davis
# https://www.lanacion.com.ar/1305256-de-donde-viene-la-vieja-costumbre-de-la-sobremesa
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 62 call
# URLs retrieved:
# https://www.lanacion.com.ar/1304972-5-navegadores-gratuitos-para-aprovechar-la-web-al-maximo
# https://www.lanacion.com.ar/1304938-vino-en-botella-damajuana-o-en-bidon-cual-preferis
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 63 call
# URLs retrieved:
# https://www.lanacion.com.ar/1304875-el-nuevo-smartphone-nokia-e7
# https://www.lanacion.com.ar/1304860-el-ranking-del-dulce-de-leche-los-10-mejores
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 64 call
# URLs retrieved:
# https://www.lanacion.com.ar/1304634-la-tecnologia-detras-de-la-victoria-de-las-leonas
# https://www.lanacion.com.ar/1298707-auriculares-funko
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 65 call
# URLs retrieved:
# https://www.lanacion.com.ar/1304318-mario-cumple-25-anos-cual-es-tu-version-favorita
# https://www.lanacion.com.ar/1304272-carla-rebecchi-vs-ellen-hoog-cual-de-las-dos-se-lleva-el-premio-a-la-mas-linda-del-mundial
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 66 call
# URLs retrieved:
# https://www.lanacion.com.ar/1303316-bloqueo-creativo-que-hacer-cuando-nos-quedamos-con-la-mente-en-blanco
# https://www.lanacion.com.ar/1303322-adidas
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 67 call
# URLs retrieved:
# https://www.lanacion.com.ar/1302970-los-10-mejores-postres-que-deberias-probar
# https://www.lanacion.com.ar/1303295-moda-5-propuestas-de-estilo-para-la-rutina-diaria
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 68 call
# URLs retrieved:
# https://www.lanacion.com.ar/1289676-transition
# https://www.lanacion.com.ar/1302615-5-sitios-para-ver-videos-on-line-alternativos-a-youtube
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 69 call
# URLs retrieved:
# https://www.lanacion.com.ar/1301949-pam-anderson-vs-carmen-electra-con-cual-de-las-dos-conejitas-te-quedarias
# https://www.lanacion.com.ar/1302295-duke-nukem-forever-el-mito-del-video-juego-imposible
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 70 call
# URLs retrieved:
# https://www.lanacion.com.ar/1302258-test-drive-bmw-x1-20-una-suv-equipado-para-el-asfalto
# https://www.lanacion.com.ar/1298715-adidas-edicion-limitada
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 71 call
# URLs retrieved:
# https://www.lanacion.com.ar/1300973-sexo-por-dinero-el-trabajo-mas-antiguo-de-la-naturaleza
# https://www.lanacion.com.ar/1300960-ryders-los-skaters-vuelven-de-la-mano-de-las-longboards
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting

# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 112 call
# URLs retrieved:
# https://www.lanacion.com.ar/1280901-mouse-microsoft
# https://www.lanacion.com.ar/1282502-volver-al-futuro-cumple-25-anos
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 113 call
# URLs retrieved:
# https://www.lanacion.com.ar/1282473-ahora-que-para-nosotros-termino-el-mundial-con-que-nos-entretenemos
# https://www.lanacion.com.ar/1280907-ahora-que-para-nosotros-termino-el-mundial-con-que-nos-entretenemos
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 114 call
# URLs retrieved:
# https://www.lanacion.com.ar/1282463-queres-hacer-un-documental-sobre-tu-vida-ridley-scott-te-lo-dirige-gratis
# https://www.lanacion.com.ar/1282215-vinos-tintos-de-guarda-10-propuestas-que-no-pueden-fallar
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 115 call
# URLs retrieved:
# https://www.lanacion.com.ar/1282161-natalia-oreiro-la-chica-de-tapa-de-la-brando-edicion-verde
# https://www.lanacion.com.ar/1281900-calu-rivero-y-luisana-lopilato-cual-de-las-dos-actrices-te-seduce-mas
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 116 call
# URLs retrieved:
# https://www.lanacion.com.ar/1280926-consejos-para-volver-a-las-pistas
# https://www.lanacion.com.ar/1280903-numero-55-julio-2010
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 117 call
# URLs retrieved:
# https://www.lanacion.com.ar/1280888-si-no-te-aguantas-un-secreto-desahogate-en-la-red
# https://www.lanacion.com.ar/1280869-microcoches-peel-p50-y-trident
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 118 call
# URLs retrieved:
# https://www.lanacion.com.ar/1280857-las-remeras-del-mundial
# https://www.lanacion.com.ar/1280541-maria-grazia-cucinotta-el-escote-mas-tentador
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 119 call
# URLs retrieved:
# https://www.lanacion.com.ar/1280201-llega-el-daimler-smart-fortwo
# https://www.lanacion.com.ar/1279922-luli-fernandez-vs-zaira-nara-quien-lleva-mejor-la-camiseta-de-la-seleccion
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 120 call
# URLs retrieved:
# https://www.lanacion.com.ar/1279897-como-elegir-un-aceite-de-oliva
# https://www.lanacion.com.ar/1279568-espana-vs-portugal-sara-carbonero-novia-de-iker-casillas-vs-irina-shayk-la-chica-de-cristiano-ronaldo-quien-gana
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 121 call
# URLs retrieved:
# https://www.lanacion.com.ar/1279593-lightheaded
# https://www.lanacion.com.ar/1279573-para-vos-cual-sera-el-resultado-del-partido-argentina-alemania
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 122 call
# URLs retrieved:
# https://www.lanacion.com.ar/1278646-hp-all-in-one-200
# https://www.lanacion.com.ar/1278638-cinco-canciones-para-salir-correr
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 123 call
# URLs retrieved:
# https://www.lanacion.com.ar/1278625-una-parodia-sobre-el-derrame-de-british-petroleum-es-un-hit-en-internet
# https://www.lanacion.com.ar/1278616-los-malditos-cuarenta
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 124 call
# URLs retrieved:
# https://www.lanacion.com.ar/1276357-nuevas-camaras-kodak
# https://www.lanacion.com.ar/1276028-motorokr-s305
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 125 call
# URLs retrieved:
# https://www.lanacion.com.ar/1278231-mia-flores-piran-vos-le-comerias-la-boca
# https://www.lanacion.com.ar/1277924-peugeot-207-compact-sedan-vs-volkswagen-voyage
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 145 call
# URLs retrieved:
# https://www.lanacion.com.ar/1267252-disenos-puma-para-el-mundial
# https://www.lanacion.com.ar/1264649-5-televisores-de-lcd-para-disfrutar-del-mundial
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 146 call
# URLs retrieved:
# https://www.lanacion.com.ar/1266785-marina-remmer-portfolio-de-una-rubia-sensual
# https://www.lanacion.com.ar/1267157-cual-es-tu-restaurante-favorito-para-comer-un-asado
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 147 call
# URLs retrieved:
# https://www.lanacion.com.ar/http://barra.conexionbrando.com/
# https://www.lanacion.com.ar/1266110-bicimotos-nino
# URLs to parse: 02
# Getting 148 call
# URLs retrieved:
# https://www.lanacion.com.ar/1266832-alerta-trepador-a-la-vista
# https://www.lanacion.com.ar/1266824-las-mejores-publicidades-de-autos
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 149 call
# URLs retrieved:
# https://www.lanacion.com.ar/1266403-jazmin-de-grazia-una-rubia-con-actitud
# https://www.lanacion.com.ar/1266453-que-cambios-harias-a-la-lista-de-maradona
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 150 call
# URLs retrieved:
# https://www.lanacion.com.ar/1266441-cual-es-tu-pelicula-de-suspenso-favorita
# https://www.lanacion.com.ar/1266437-asus-eee-keyboard-pc
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 151 call
# URLs retrieved:
# https://www.lanacion.com.ar/1266413-6-buenos-vinos-en-botella-chica
# https://www.lanacion.com.ar/1266135-el-mundial-de-las-marcas-pepsi-vs-coca-cola
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 152 call
# URLs retrieved:
# https://www.lanacion.com.ar/1266106-adidas-micoach
# https://www.lanacion.com.ar/1266087-los-autos-de-nuestra-infancia
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 153 call
# URLs retrieved:
# https://www.lanacion.com.ar/1265732-charlize-theron-vs-scarlett-johansson-quien-te-seduce-mas
# https://www.lanacion.com.ar/1265782-el-equipo-ideal-para-jugar-el-mundial
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 154 call
# URLs retrieved:
# https://www.lanacion.com.ar/1265757-vinos-para-un-el-menu-del-bicentenario
# https://www.lanacion.com.ar/1265745-mercedes-oviedo-vs-zaira-nara-quien-te-seduce-mas
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 155 call
# URLs retrieved:
# https://www.lanacion.com.ar/1265743-ines-estevez-vs-leticia-bredice-quien-te-gusta-mas
# https://www.lanacion.com.ar/1265736-cual-es-tu-medio-de-transporte-preferido-por-que
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 156 call
# URLs retrieved:
# https://www.lanacion.com.ar/1262206-diesel-only-the-brave-por-artoyz
# https://www.lanacion.com.ar/1264660-terapias-online-cuando-el-consultorio-esta-en-tu-computadora
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 157 call
# URLs retrieved:
# https://www.lanacion.com.ar/1264224-10-morochas-que-levantan-temperatura
# https://www.lanacion.com.ar/1262205-botines-nike
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 158 call
# URLs retrieved:
# https://www.lanacion.com.ar/1263898-bmw-x5-y-x6-m-extremas-en-todo-sentido
# https://www.lanacion.com.ar/1263890-las-publicidades-mas-exitosas-del-mundial
# URLs to parse: 02
# parsing 01 URL
# parsing 02 URL
# Getting 159 call

# %%
articles = pickle.load( open('/home/fer/text_mining/brando.p', "rb" ) )
print(len(articles.keys()))
articles['https://www.lanacion.com.ar/1415461-la-politica-viste-a-la-moda-lilita-carrio']
# Out:
# 5154
# ['17  de octubre de 2011 \xa0• 14:38',
#  'La política viste a la moda: Lilita Carrio',
#  '\n\nLilita Carrio, nacida Elisa María Avelina Carrió, es una de las figuras políticas más erráticas del escenario nacional: de los 23 puntos de 2007 se deslizó en caída libre al penoso 3,30 por ciento de las recientes internas abiertas, \r\n resultado que la obligó  a hacer un \r\n mea culpa  como buena cristiana ( \r\n "Soy la razón de la derrota"  ). Su biografía, extensa y notoria, tiene un pico de popularidad durante la crisis del menemismo, el gobierno de la Alianza y 2001, cuando el espíritu de hastío colectivo y derrumbe social fogoneó su rol de custodia de los otrora tibios valores de la honestidad, la decencia y la administración.Los contornos complejos de su posición pública, a la vez, refuerzan este rasgo institucionalista puro con una clara vocación profética que pegó bastante en momentos de la historia argentina que tenían mucho sabor a fin del mundo y Apocalipsis. En efecto, \r\n Lilita es una chaqueña compleja, por momentos lúcida y por momentos totalmente perdida en el triángulo de las Bermudas que forman la Biblia, el hedonismo y su incapacidad de construir partidos sin fracturarlos. También es un maravilloso caso de estudio para abordar el objeto de esta tradicionalísima columna, esto es, la relación no siempre existente \x96pero en este caso sí\x96 entre una personalidad política y un guardarropas. Porque, sin lugar a dudas, el vestuario de Lilita es un compilado de prendas salidas de \r\n outfits  que no tienen nada que ver entre sí, \r\n un pastiche de elementos que no siempre armonizan,  un collage, en suma, un \r\n happening  que llama a recordar el situacionismo francés o el punk inglés, entre otras expresiones artísticas típicas del poscapitalismo de servicios.Como ya mencionamos en otras oportunidades, el pelo es la punta del iceberg. \r\n En el caso de Carrió, tenemos un platinado sin volumen y llovido, medio descuidado, que ayuda a enfatizar los aros ochentosos y que pega de manera controversial con el tostado rústico y semiartificial de la piel.  Si a esta combineta le agregamos el labial rojo supernova, lo que tenemos es un maridaje dudoso aunque, esto sí hay que decirlo, muy urbano, que en el ámbito político es óptimo a la hora de establecer alianzas estratégicas con el sector agropecuario y producir contrastes.\n La capa es también un distintivo personal de Carrió  que ha marcado tendencia en los últimos años entre las señoras de alto poder adquisitivo. Podríamos definir el \r\n look,  a riesgos de ser horribles personas, como un \r\n "carpa-chic",  que se completa con la pañoleta o chalina blanca y negra al viento como único elemento de color que, suponemos, intenta neutralizar con pobre éxito la línea platinado-zanahoria que domina el rostro.En la cartera se cae todo el mito de la oposición a Cristina porque, si se fijan bien, es una, oh sí, Louis Vuitton. ¿No era un símbolo innecesario de riqueza? \r\n ¿Por qué nadie habla de la cartera Louis Vuitton de Elisa Carrió?  Bueno, una respuesta posible a esta última pregunta es que Carrió, a diferencia de Cristina, la acompaña de un atuendo desparejo e inconsistente que la hace pasar absolutamene inadvertida.Bueno, llegamos al tercer momento polémico: \r\n las calzas, que a pesar de que están muy de moda en la franja etaria de los 18-25, no creemos que sean adecuadas para una persona que, practique la profesión que practique, busque verse elegante.  Aun si engancháramos a la líder de la Coalición Cívica en un momento informal, de entrecasa un domingo, de más está decir que los aros, la chalina, la capa y las calzas no pueden ir juntas jamás, incluso en la colección \r\n homeless  de \r\n\nJacobim Mugatu.Bueno, que quede en claro una cosa: \r\n las botas \r\n NO  pegan.  Deberían ser negras o blancas o deberían combinar con la cartera. Y no hay mucho más para decir.\n Mantenete al tanto de las actualizaciones de ConexiónBrando.com a través de \r\nTwitter. Seguinos en \r\n@ConexionBrando\nLos comentarios publicados son de exclusiva responsabilidad  ...
