# %% [markdown]
# ## Scraper para Proyectos de ley del Congreso de la Nación Argentina.
# #### Objetivo: recopilar la información de firmantes, dictámenes y cámara iniciadora de todos los proyectos de ley publicados por el sitio web de la Honorable Cámara de Diputados de la Nación desde junio de 2006 hasta julio de 2018.

# %% [markdown]
# ### Cargo las librerías

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
import urllib.parse
import requests
import pickle
import time
import re
from tqdm import tqdm
from bs4 import BeautifulSoup
from itertools import cycle

# %% [markdown]
# ### Completo el formulario con la información requerida en la web de la HCDN (Proyecto 1)

# %%
url = "https://www.hcdn.gob.ar/proyectos/resultados-buscador.html"

querystring = {
  "strCantPagina":"20",
  "strMostrarFirmantes":"on",
  "strMostrarComisiones":"on",
  "strMostrarDictamenes":"on",
  "strMostrarTramites":"on"
}

response = requests.request("POST", url, params=querystring)

# %% [markdown]
# #### Itero sobre todas las páginas para descargar todos los proyectos

# %%
paginas = []
pags_limite = 15000
sleep = 0.1

for page in range(1,pags_limite):
    time.sleep(sleep)
    link = '{}?pagina={}'.format(url, page)
    cookies = response.cookies
    response_iterative = requests.request("GET", link, cookies=cookies)
    paginas.append(response_iterative.text)
    with open("proyectos_congreso.p", "wb") as fp:
        pickle.dump(paginas, fp)
    print('El {}, páginas {}'.format(time.asctime(), len(paginas)))
# Out:
# El Mon Oct 22 00:06:13 2018, páginas 1
# El Mon Oct 22 00:06:15 2018, páginas 2
# El Mon Oct 22 00:06:17 2018, páginas 3
# El Mon Oct 22 00:06:21 2018, páginas 4
# El Mon Oct 22 00:06:24 2018, páginas 5
# El Mon Oct 22 00:06:27 2018, páginas 6
# El Mon Oct 22 00:06:31 2018, páginas 7
# El Mon Oct 22 00:06:34 2018, páginas 8
# El Mon Oct 22 00:06:38 2018, páginas 9
# El Mon Oct 22 00:06:40 2018, páginas 10
# El Mon Oct 22 00:06:44 2018, páginas 11
# El Mon Oct 22 00:06:47 2018, páginas 12
# El Mon Oct 22 00:06:50 2018, páginas 13
# El Mon Oct 22 00:06:53 2018, páginas 14
# El Mon Oct 22 00:06:56 2018, páginas 15
# El Mon Oct 22 00:06:59 2018, páginas 16
# El Mon Oct 22 00:07:02 2018, páginas 17
# El Mon Oct 22 00:07:06 2018, páginas 18
# El Mon Oct 22 00:07:09 2018, páginas 19
# El Mon Oct 22 00:07:12 2018, páginas 20
# El Mon Oct 22 00:07:15 2018, páginas 21
# El Mon Oct 22 00:07:18 2018, páginas 22
# El Mon Oct 22 00:07:22 2018, páginas 23
# El Mon Oct 22 00:07:24 2018, páginas 24
# El Mon Oct 22 00:07:28 2018, páginas 25
# El Mon Oct 22 00:07:32 2018, páginas 26
# El Mon Oct 22 00:07:39 2018, páginas 27
# El Mon Oct 22 00:07:42 2018, páginas 28
# El Mon Oct 22 00:07:45 2018, páginas 29
# El Mon Oct 22 00:07:48 2018, páginas 30
# El Mon Oct 22 00:07:51 2018, páginas 31
# El Mon Oct 22 00:07:55 2018, páginas 32
# El Mon Oct 22 00:07:58 2018, páginas 33
# El Mon Oct 22 00:08:02 2018, páginas 34
# El Mon Oct 22 00:08:07 2018, páginas 35
# El Mon Oct 22 00:08:11 2018, páginas 36
# El Mon Oct 22 00:08:15 2018, páginas 37
# El Mon Oct 22 00:08:19 2018, páginas 38
# El Mon Oct 22 00:08:23 2018, páginas 39
# El Mon Oct 22 00:08:26 2018, páginas 40
# El Mon Oct 22 00:08:30 2018, páginas 41
# El Mon Oct 22 00:08:34 2018, páginas 42
# El Mon Oct 22 00:08:36 2018, páginas 43
# El Mon Oct 22 00:08:39 2018, páginas 44
# El Mon Oct 22 00:08:42 2018, páginas 45
# El Mon Oct 22 00:08:46 2018, páginas 46
# El Mon Oct 22 00:08:49 2018, páginas 47
# El Mon Oct 22 00:08:53 2018, páginas 48
# El Mon Oct 22 00:08:56 2018, páginas 49
# El Mon Oct 22 00:09:00 2018, páginas 50
# El Mon Oct 22 00:09:02 2018, páginas 51
# El Mon Oct 22 00:09:05 2018, páginas 52
# El Mon Oct 22 00:09:07 2018, páginas 53
# El Mon Oct 22 00:09:11 2018, páginas 54
# El Mon Oct 22 00:09:14 2018, páginas 55
# El Mon Oct 22 00:09:17 2018, páginas 56
# El Mon Oct 22 00:09:21 2018, páginas 57
# El Mon Oct 22 00:09:24 2018, páginas 58
# El Mon Oct 22 00:09:29 2018, páginas 59
# El Mon Oct 22 00:09:32 2018, páginas 60
# El Mon Oct 22 00:09:36 2018, páginas 61
# El Mon Oct 22 00:09:40 2018, páginas 62
# El Mon Oct 22 00:09:43 2018, páginas 63
# El Mon Oct 22 00:09:46 2018, páginas 64
# El Mon Oct 22 00:09:49 2018, páginas 65
# El Mon Oct 22 00:09:53 2018, páginas 66
# El Mon Oct 22 00:09:56 2018, páginas 67
# El Mon Oct 22 00:09:59 2018, páginas 68
# El Mon Oct 22 00:10:02 2018, páginas 69
# El Mon Oct 22 00:10:04 2018, páginas 70
# El Mon Oct 22 00:10:07 2018, páginas 71
# El Mon Oct 22 00:10:10 2018, páginas 72
# El Mon Oct 22 00:10:13 2018, páginas 73
# El Mon Oct 22 00:10:16 2018, páginas 74
# El Mon Oct 22 00:10:19 2018, páginas 75
# El Mon Oct 22 00:10:21 2018, páginas 76
# El Mon Oct 22 00:10:24 2018, páginas 77
# El Mon Oct 22 00:10:26 2018, páginas 78
# El Mon Oct 22 00:10:29 2018, páginas 79
# El Mon Oct 22 00:10:32 2018, páginas 80
# El Mon Oct 22 00:10:36 2018, páginas 81
# El Mon Oct 22 00:10:39 2018, páginas 82
# El Mon Oct 22 00:10:41 2018, páginas 83
# El Mon Oct 22 00:10:45 2018, páginas 84
# El Mon Oct 22 00:10:48 2018, páginas 85
# El Mon Oct 22 00:10:51 2018, páginas 86
# El Mon Oct 22 00:10:54 2018, páginas 87
# El Mon Oct 22 00:10:57 2018, páginas 88
# El Mon Oct 22 00:11:00 2018, páginas 89
# El Mon Oct 22 00:11:03 2018, páginas 90
# El Mon Oct 22 00:11:06 2018, páginas 91
# El Mon Oct 22 00:11:10 2018, páginas 92
# El Mon Oct 22 00:11:13 2018, páginas 93
# El Mon Oct 22 00:11:16 2018, páginas 94
# El Mon Oct 22 00:11:19 2018, páginas 95
# El Mon Oct 22 00:11:23 2018, páginas 96
# El Mon Oct 22 00:11:25 2018, páginas 97
# El Mon Oct 22 00:11:28 2018, páginas 98
# El Mon Oct 22 00:11:31 2018, páginas 99
# El Mon Oct 22 00:11:34 2018, páginas 100
# El Mon Oct 22 00:11:38 2018, páginas 101
# El Mon Oct 22 00:11:41 2018, páginas 102
# El Mon Oct 22 00:11:44 2018, páginas 103
# El Mon Oct 22 00:11:46 2018, páginas 104
# El Mon Oct 22 00:11:49 2018, páginas 105
# El Mon Oct 22 00:11:52 2018, páginas 106
# El Mon Oct 22 00:11:56 2018, páginas 107
# El Mon Oct 22 00:11:59 2018, páginas 108
# El Mon Oct 22 00:12:02 2018, páginas 109
# El Mon Oct 22 00:12:06 2018, páginas 110
# El Mon Oct 22 00:12:08 2018, páginas 111
# El Mon Oct 22 00:12:11 2018, páginas 112
# El Mon Oct 22 00:12:14 2018, páginas 113
# El Mon Oct 22 00:12:17 2018, páginas 114
# El Mon Oct 22 00:12:20 2018, páginas 115
# El Mon Oct 22 00:12:24 2018, páginas 116
# El Mon Oct 22 00:12:27 2018, páginas 117
# El Mon Oct 22 00:12:31 2018, páginas 118
# El Mon Oct 22 00:12:34 2018, páginas 119
# El Mon Oct 22 00:12:37 2018, páginas 120
# El Mon Oct 22 00:12:40 2018, páginas 121
# El Mon Oct 22 00:12:43 2018, páginas 122
# El Mon Oct 22 00:12:46 2018, páginas 123
# El Mon Oct 22 00:12:50 2018, páginas 124
# El Mon Oct 22 00:12:53 2018, páginas 125
# El Mon Oct 22 00:12:56 2018, páginas 126
# El Mon Oct 22 00:13:00 2018, páginas 127
# El Mon Oct 22 00:13:03 2018, páginas 128
# El Mon Oct 22 00:13:06 2018, páginas 129
# El Mon Oct 22 00:13:09 2018, páginas 130
# El Mon Oct 22 00:13:12 2018, páginas 131
# El Mon Oct 22 00:13:14 2018, páginas 132
# El Mon Oct 22 00:13:17 2018, páginas 133
# El Mon Oct 22 00:13:19 2018, páginas 134
# El Mon Oct 22 00:13:23 2018, páginas 135
# El Mon Oct 22 00:13:25 2018, páginas 136
# El Mon Oct 22 00:13:28 2018, páginas 137
# El Mon Oct 22 00:13:32 2018, páginas 138
# El Mon Oct 22 00:13:35 2018, páginas 139
# El Mon Oct 22 00:13:39 2018, páginas 140
# El Mon Oct 22 00:13:42 2018, páginas 141
# El Mon Oct 22 00:13:44 2018, páginas 142
# El Mon Oct 22 00:13:48 2018, páginas 143
# El Mon Oct 22 00:13:51 2018, páginas 144
# El Mon Oct 22 00:13:55 2018, páginas 145
# El Mon Oct 22 00:13:57 2018, páginas 146
# El Mon Oct 22 00:14:00 2018, páginas 147
# El Mon Oct 22 00:14:03 2018, páginas 148
# El Mon Oct 22 00:14:06 2018, páginas 149
# El Mon Oct 22 00:14:08 2018, páginas 150
# El Mon Oct 22 00:14:11 2018, páginas 151
# El Mon Oct 22 00:14:13 2018, páginas 152
# El Mon Oct 22 00:14:17 2018, páginas 153
# El Mon Oct 22 00:14:21 2018, páginas 154
# El Mon Oct 22 00:14:25 2018, páginas 155
# El Mon Oct 22 00:14:28 2018, páginas 156
# El Mon Oct 22 00:14:30 2018, páginas 157
# El Mon Oct 22 00:14:34 2018, páginas 158
# El Mon Oct 22 00:14:37 2018, páginas 159
# El Mon Oct 22 00:14:40 2018, páginas 160
# El Mon Oct 22 00:14:42 2018, páginas 161
# El Mon Oct 22 00:14:46 2018, páginas 162
# El Mon Oct 22 00:14:48 2018, páginas 163
# El Mon Oct 22 00:14:51 2018, páginas 164
# El Mon Oct 22 00:14:55 2018, páginas 165
# El Mon Oct 22 00:14:59 2018, páginas 166
# El Mon Oct 22 00:15:02 2018, páginas 167
# El Mon Oct 22 00:15:05 2018, páginas 168
# El Mon Oct 22 00:15:07 2018, páginas 169
# El Mon Oct 22 00:15:10 2018, páginas 170
# El Mon Oct 22 00:15:15 2018, páginas 171
# El Mon Oct 22 00:15:18 2018, páginas 172
# El Mon Oct 22 00:15:20 2018, páginas 173
# El Mon Oct 22 00:15:25 2018, páginas 174
# El Mon Oct 22 00:15:28 2018, páginas 175
# El Mon Oct 22 00:15:30 2018, páginas 176
# El Mon Oct 22 00:15:32 2018, páginas 177
# El Mon Oct 22 00:15:35 2018, páginas 178
# El Mon Oct 22 00:15:38 2018, páginas 179
# El Mon Oct 22 00:15:41 2018, páginas 180
# El Mon Oct 22 00:15:43 2018, páginas 181
# El Mon Oct 22 00:15:47 2018, páginas 182
# El Mon Oct 22 00:15:50 2018, páginas 183
# El Mon Oct 22 00:15:54 2018, páginas 184
# El Mon Oct 22 00:15:56 2018, páginas 185
# El Mon Oct 22 00:16:00 2018, páginas 186
# El Mon Oct 22 00:16:04 2018, páginas 187
# El Mon Oct 22 00:16:06 2018, páginas 188
# El Mon Oct 22 00:16:09 2018, páginas 189
# El Mon Oct 22 00:16:12 2018, páginas 190
# El Mon Oct 22 00:16:15 2018, páginas 191
# El Mon Oct 22 00:16:17 2018, páginas 192
# El Mon Oct 22 00:16:20 2018, páginas 193
# El Mon Oct 22 00:16:23 2018, páginas 194
# El Mon Oct 22 00:16:27 2018, páginas 195
# El Mon Oct 22 00:16:30 2018, páginas 196
# El Mon Oct 22 00:16:33 2018, páginas 197
# El Mon Oct 22 00:16:36 2018, páginas 198
# El Mon Oct 22 00:16:40 2018, páginas 199
# El Mon Oct 22 00:16:43 2018, páginas 200
# El Mon Oct 22 00:16:45 2018, páginas 201
# El Mon Oct 22 00:16:49 2018, páginas 202
# El Mon Oct 22 00:16:53 2018, páginas 203
# El Mon Oct 22 00:16:56 2018, páginas 204
# El Mon Oct 22 00:16:59 2018, páginas 205
# El Mon Oct 22 00:17:02 2018, páginas 206
# El Mon Oct 22 00:17:06 2018, páginas 207
# El Mon Oct 22 00:17:09 2018, páginas 208
# El Mon Oct 22 00:17:13 2018, páginas 209
# El Mon Oct 22 00:17:16 2018, páginas 210
# El Mon Oct 22 00:17:18 2018, páginas 211
# El Mon Oct 22 00:17:21 2018, páginas 212
# El Mon Oct 22 00:17:24 2018, páginas 213
# El Mon Oct 22 00:17:27 2018, páginas 214
# El Mon Oct 22 00:17:30 2018, páginas 215
# El Mon Oct 22 00:17:33 2018, páginas 216
# El Mon Oct 22 00:17:36 2018, páginas 217
# El Mon Oct 22 00:17:42 2018, páginas 218
# El Mon Oct 22 00:17:45 2018, páginas 219
# El Mon Oct 22 00:17:48 2018, páginas 220
# El Mon Oct 22 00:17:53 2018, páginas 221
# El Mon Oct 22 00:17:55 2018, páginas 222
# El Mon Oct 22 00:17:58 2018, páginas 223
# El Mon Oct 22 00:18:02 2018, páginas 224
# El Mon Oct 22 00:18:04 2018, páginas 225
# El Mon Oct 22 00:18:07 2018, páginas 226
# El Mon Oct 22 00:18:11 2018, páginas 227
# El Mon Oct 22 00:18:14 2018, páginas 228
# El Mon Oct 22 00:18:18 2018, páginas 229
# El Mon Oct 22 00:18:22 2018, páginas 230
# El Mon Oct 22 00:18:24 2018, páginas 231
# El Mon Oct 22 00:18:27 2018, páginas 232
# El Mon Oct 22 00:18:31 2018, páginas 233
# El Mon Oct 22 00:18:34 2018, páginas 234
# El Mon Oct 22 00:18:37 2018, páginas 235
# El Mon Oct 22 00:18:40 2018, páginas 236
# El Mon Oct 22 00:18:43 2018, páginas 237
# El Mon Oct 22 00:18:46 2018, páginas 238
# El Mon Oct 22 00:18:50 2018, páginas 239
# El Mon Oct 22 00:18:54 2018, páginas 240
# El Mon Oct 22 00:18:56 2018, páginas 241
# El Mon Oct 22 00:19:00 2018, páginas 242
# El Mon Oct 22 00:19:03 2018, páginas 243
# El Mon Oct 22 00:19:06 2018, páginas 244
# El Mon Oct 22 00:19:09 2018, páginas 245
# El Mon Oct 22 00:19:12 2018, páginas 246
# El Mon Oct 22 00:19:15 2018, páginas 247
# El Mon Oct 22 00:19:19 2018, páginas 248
# El Mon Oct 22 00:19:22 2018, páginas 249
# El Mon Oct 22 00:19:25 2018, páginas 250
# El Mon Oct 22 00:19:28 2018, páginas 251
# El Mon Oct 22 00:19:31 2018, páginas 252
# El Mon Oct 22 00:19:34 2018, páginas 253
# El Mon Oct 22 00:19:37 2018, páginas 254
# El Mon Oct 22 00:19:41 2018, páginas 255
# El Mon Oct 22 00:19:44 2018, páginas 256
# El Mon Oct 22 00:19:47 2018, páginas 257
# El Mon Oct 22 00:19:50 2018, páginas 258
# El Mon Oct 22 00:19:54 2018, páginas 259
# El Mon Oct 22 00:19:58 2018, páginas 260
# El Mon Oct 22 00:20:01 2018, páginas 261
# El Mon Oct 22 00:20:03 2018, páginas 262
# El Mon Oct 22 00:20:06 2018, páginas 263
# El Mon Oct 22 00:20:09 2018, páginas 264
# El Mon Oct 22 00:20:12 2018, páginas 265
# El Mon Oct 22 00:20:15 2018, páginas 266
# El Mon Oct 22 00:20:19 2018, páginas 267
# El Mon Oct 22 00:20:23 2018, páginas 268
# El Mon Oct 22 00:20:26 2018, páginas 269
# El Mon Oct 22 00:20:29 2018, páginas 270
# El Mon Oct 22 00:20:31 2018, páginas 271
# El Mon Oct 22 00:20:34 2018, páginas 272
# El Mon Oct 22 00:20:37 2018, páginas 273
# El Mon Oct 22 00:20:41 2018, páginas 274
# El Mon Oct 22 00:20:44 2018, páginas 275
# El Mon Oct 22 00:20:47 2018, páginas 276
# El Mon Oct 22 00:20:51 2018, páginas 277
# El Mon Oct 22 00:20:53 2018, páginas 278
# El Mon Oct 22 00:20:56 2018, páginas 279
# El Mon Oct 22 00:20:59 2018, páginas 280
# El Mon Oct 22 00:21:02 2018, páginas 281
# El Mon Oct 22 00:21:05 2018, páginas 282
# El Mon Oct 22 00:21:08 2018, páginas 283
# El Mon Oct 22 00:21:12 2018, páginas 284
# El Mon Oct 22 00:21:16 2018, páginas 285
# El Mon Oct 22 00:21:20 2018, páginas 286
# El Mon Oct 22 00:21:23 2018, páginas 287
# El Mon Oct 22 00:21:26 2018, páginas 288
# El Mon Oct 22 00:21:29 2018, páginas 289
# El Mon Oct 22 00:21:32 2018, páginas 290
# El Mon Oct 22 00:21:35 2018, páginas 291
# El Mon Oct 22 00:21:38 2018, páginas 292
# El Mon Oct 22 00:21:41 2018, páginas 293
# El Mon Oct 22 00:21:45 2018, páginas 294
# El Mon Oct 22 00:21:48 2018, páginas 295
# El Mon Oct 22 00:21:50 2018, páginas 296
# El Mon Oct 22 00:21:54 2018, páginas 297
# El Mon Oct 22 00:21:57 2018, páginas 298
# El Mon Oct 22 00:22:00 2018, páginas 299
# El Mon Oct 22 00:22:04 2018, páginas 300
# El Mon Oct 22 00:22:08 2018, páginas 301
# El Mon Oct 22 00:22:10 2018, páginas 302
# El Mon Oct 22 00:22:14 2018, páginas 303
# El Mon Oct 22 00:22:17 2018, páginas 304
# El Mon Oct 22 00:22:21 2018, páginas 305
# El Mon Oct 22 00:22:23 2018, páginas 306
# El Mon Oct 22 00:22:26 2018, páginas 307
# El Mon Oct 22 00:22:30 2018, páginas 308
# El Mon Oct 22 00:22:34 2018, páginas 309
# El Mon Oct 22 00:22:36 2018, páginas 310
# El Mon Oct 22 00:22:39 2018, páginas 311
# El Mon Oct 22 00:22:41 2018, páginas 312
# El Mon Oct 22 00:22:45 2018, páginas 313
# El Mon Oct 22 00:22:48 2018, páginas 314
# El Mon Oct 22 00:22:51 2018, páginas 315
# El Mon Oct 22 00:22:54 2018, páginas 316
# El Mon Oct 22 00:22:58 2018, páginas 317
# El Mon Oct 22 00:23:01 2018, páginas 318
# El Mon Oct 22 00:23:04 2018, páginas 319
# El Mon Oct 22 00:23:06 2018, páginas 320
# El Mon Oct 22 00:23:09 2018, páginas 321
# El Mon Oct 22 00:23:13 2018, páginas 322
# El Mon Oct 22 00:23:16 2018, páginas 323
# El Mon Oct 22 00:23:19 2018, páginas 324
# El Mon Oct 22 00:23:22 2018, páginas 325
# El Mon Oct 22 00:23:26 2018, páginas 326
# El Mon Oct 22 00:23:30 2018, páginas 327
# El Mon Oct 22 00:23:34 2018, páginas 328
# El Mon Oct 22 00:23:37 2018, páginas 329
# El Mon Oct 22 00:23:41 2018, páginas 330
# El Mon Oct 22 00:23:44 2018, páginas 331
# El Mon Oct 22 00:23:48 2018, páginas 332
# El Mon Oct 22 00:23:51 2018, páginas 333
# El Mon Oct 22 00:23:55 2018, páginas 334
# El Mon Oct 22 00:23:58 2018, páginas 335
# El Mon Oct 22 00:24:02 2018, páginas 336
# El Mon Oct 22 00:24:05 2018, páginas 337
# El Mon Oct 22 00:24:08 2018, páginas 338
# El Mon Oct 22 00:24:12 2018, páginas 339
# El Mon Oct 22 00:24:15 2018, páginas 340
# El Mon Oct 22 00:24:20 2018, páginas 341
# El Mon Oct 22 00:24:23 2018, páginas 342
# El Mon Oct 22 00:24:27 2018, páginas 343
# El Mon Oct 22 00:24:30 2018, páginas 344
# El Mon Oct 22 00:24:34 2018, páginas 345
# El Mon Oct 22 00:24:37 2018, páginas 346
# El Mon Oct 22 00:24:40 2018, páginas 347
# El Mon Oct 22 00:24:44 2018, páginas 348
# El Mon Oct 22 00:24:47 2018, páginas 349
# El Mon Oct 22 00:24:51 2018, páginas 350
# El Mon Oct 22 00:24:54 2018, páginas 351
# El Mon Oct 22 00:24:58 2018, páginas 352
# El Mon Oct 22 00:25:00 2018, páginas 353
# El Mon Oct 22 00:25:04 2018, páginas 354
# El Mon Oct 22 00:25:08 2018, páginas 355
# El Mon Oct 22 00:25:11 2018, páginas 356
# El Mon Oct 22 00:25:15 2018, páginas 357
# El Mon Oct 22 00:25:18 2018, páginas 358
# El Mon Oct 22 00:25:22 2018, páginas 359
# El Mon Oct 22 00:25:25 2018, páginas 360
# El Mon Oct 22 00:25:29 2018, páginas 361
# El Mon Oct 22 00:25:32 2018, páginas 362
# El Mon Oct 22 00:25:36 2018, páginas 363
# El Mon Oct 22 00:25:39 2018, páginas 364
# El Mon Oct 22 00:25:43 2018, páginas 365
# El Mon Oct 22 00:25:46 2018, páginas 366
# El Mon Oct 22 00:25:50 2018, páginas 367
# El Mon Oct 22 00:25:53 2018, páginas 368
# El Mon Oct 22 00:25:58 2018, páginas 369
# El Mon Oct 22 00:26:01 2018, páginas 370
# El Mon Oct 22 00:26:04 2018, páginas 371
# El Mon Oct 22 00:26:08 2018, páginas 372
# El Mon Oct 22 00:26:11 2018, páginas 373
# El Mon Oct 22 00:26:15 2018, páginas 374
# El Mon Oct 22 00:26:19 2018, páginas 375
# El Mon Oct 22 00:26:22 2018, páginas 376
# El Mon Oct 22 00:26:25 2018, páginas 377
# El Mon Oct 22 00:26:29 2018, páginas 378
# El Mon Oct 22 00:26:32 2018, páginas 379
# El Mon Oct 22 00:26:36 2018, páginas 380
# El Mon Oct 22 00:26:39 2018, páginas 381
# El Mon Oct 22 00:26:43 2018, páginas 382
# El Mon Oct 22 00:26:46 2018, páginas 383
# El Mon Oct 22 00:26:49 2018, páginas 384
# El Mon Oct 22 00:26:52 2018, páginas 385
# El Mon Oct 22 00:26:56 2018, páginas 386
# El Mon Oct 22 00:27:00 2018, páginas 387
# El Mon Oct 22 00:27:04 2018, páginas 388
# El Mon Oct 22 00:27:08 2018, páginas 389
# El Mon Oct 22 00:27:13 2018, páginas 390
# El Mon Oct 22 00:27:16 2018, páginas 391
# El Mon Oct 22 00:27:23 2018, páginas 392
# El Mon Oct 22 00:27:26 2018, páginas 393
# El Mon Oct 22 00:27:31 2018, páginas 394
# El Mon Oct 22 00:27:35 2018, páginas 395
# El Mon Oct 22 00:27:39 2018, páginas 396
# El Mon Oct 22 00:27:42 2018, páginas 397
# El Mon Oct 22 00:27:46 2018, páginas 398
# El Mon Oct 22 00:27:49 2018, páginas 399
# El Mon Oct 22 00:27:53 2018, páginas 400
# El Mon Oct 22 00:27:56 2018, páginas 401
# El Mon Oct 22 00:28:00 2018, páginas 402
# El Mon Oct 22 00:28:03 2018, páginas 403
# El Mon Oct 22 00:28:07 2018, páginas 404
# El Mon Oct 22 00:28:11 2018, páginas 405
# El Mon Oct 22 00:28:13 2018, páginas 406
# El Mon Oct 22 00:28:17 2018, páginas 407
# El Mon Oct 22 00:28:20 2018, páginas 408
# El Mon Oct 22 00:28:24 2018, páginas 409
# El Mon Oct 22 00:28:27 2018, páginas 410
# El Mon Oct 22 00:28:31 2018, páginas 411
# El Mon Oct 22 00:28:33 2018, páginas 412
# El Mon Oct 22 00:28:36 2018, páginas 413
# El Mon Oct 22 00:28:40 2018, páginas 414
# El Mon Oct 22 00:28:44 2018, páginas 415
# El Mon Oct 22 00:28:48 2018, páginas 416
# El Mon Oct 22 00:28:51 2018, páginas 417
# El Mon Oct 22 00:28:54 2018, páginas 418
# El Mon Oct 22 00:28:57 2018, páginas 419
# El Mon Oct 22 00:29:00 2018, páginas 420
# El Mon Oct 22 00:29:04 2018, páginas 421
# El Mon Oct 22 00:29:07 2018, páginas 422
# El Mon Oct 22 00:29:11 2018, páginas 423
# El Mon Oct 22 00:29:14 2018, páginas 424
# El Mon Oct 22 00:29:17 2018, páginas 425
# El Mon Oct 22 00:29:20 2018, páginas 426
# El Mon Oct 22 00:29:24 2018, páginas 427
# El Mon Oct 22 00:29:27 2018, páginas 428
# El Mon Oct 22 00:29:31 2018, páginas 429
# El Mon Oct 22 00:29:34 2018, páginas 430
# El Mon Oct 22 00:29:38 2018, páginas 431
# El Mon Oct 22 00:29:41 2018, páginas 432
# El Mon Oct 22 00:29:45 2018, páginas 433
# El Mon Oct 22 00:29:48 2018, páginas 434
# El Mon Oct 22 00:29:52 2018, páginas 435
# El Mon Oct 22 00:29:55 2018, páginas 436
# El Mon Oct 22 00:29:58 2018, páginas 437
# El Mon Oct 22 00:30:01 2018, páginas 438
# El Mon Oct 22 00:30:04 2018, páginas 439
# El Mon Oct 22 00:30:08 2018, páginas 440
# El Mon Oct 22 00:30:12 2018, páginas 441
# El Mon Oct 22 00:30:15 2018, páginas 442
# El Mon Oct 22 00:30:19 2018, páginas 443
# El Mon Oct 22 00:30:22 2018, páginas 444
# El Mon Oct 22 00:30:24 2018, páginas 445
# El Mon Oct 22 00:30:27 2018, páginas 446
# El Mon Oct 22 00:30:29 2018, páginas 447
# El Mon Oct 22 00:30:32 2018, páginas 448
# El Mon Oct 22 00:30:35 2018, páginas 449
# El Mon Oct 22 00:30:40 2018, páginas 450
# El Mon Oct 22 00:30:43 2018, páginas 451
# El Mon Oct 22 00:30:47 2018, páginas 452
# El Mon Oct 22 00:30:50 2018, páginas 453
# El Mon Oct 22 00:30:54 2018, páginas 454
# El Mon Oct 22 00:30:57 2018, páginas 455
# El Mon Oct 22 00:31:00 2018, páginas 456
# El Mon Oct 22 00:31:04 2018, páginas 457
# El Mon Oct 22 00:31:07 2018, páginas 458
# El Mon Oct 22 00:31:10 2018, páginas 459
# El Mon Oct 22 00:31:14 2018, páginas 460
# El Mon Oct 22 00:31:17 2018, páginas 461
# El Mon Oct 22 00:31:20 2018, páginas 462
# El Mon Oct 22 00:31:23 2018, páginas 463
# El Mon Oct 22 00:31:26 2018, páginas 464
# El Mon Oct 22 00:31:30 2018, páginas 465
# El Mon Oct 22 00:31:34 2018, páginas 466
# El Mon Oct 22 00:31:37 2018, páginas 467
# El Mon Oct 22 00:31:40 2018, páginas 468
# El Mon Oct 22 00:31:44 2018, páginas 469
# El Mon Oct 22 00:31:48 2018, páginas 470
# El Mon Oct 22 00:31:51 2018, páginas 471
# El Mon Oct 22 00:31:59 2018, páginas 472
# El Mon Oct 22 00:32:03 2018, páginas 473
# El Mon Oct 22 00:32:06 2018, páginas 474
# El Mon Oct 22 00:32:09 2018, páginas 475
# El Mon Oct 22 00:32:12 2018, páginas 476
# El Mon Oct 22 00:32:16 2018, páginas 477
# El Mon Oct 22 00:32:21 2018, páginas 478
# El Mon Oct 22 00:32:24 2018, páginas 479
# El Mon Oct 22 00:32:27 2018, páginas 480
# El Mon Oct 22 00:32:31 2018, páginas 481
# El Mon Oct 22 00:32:34 2018, páginas 482
# El Mon Oct 22 00:32:37 2018, páginas 483
# El Mon Oct 22 00:32:41 2018, páginas 484
# El Mon Oct 22 00:32:44 2018, páginas 485
# El Mon Oct 22 00:32:48 2018, páginas 486
# El Mon Oct 22 00:32:52 2018, páginas 487
# El Mon Oct 22 00:32:54 2018, páginas 488
# El Mon Oct 22 00:32:59 2018, páginas 489
# El Mon Oct 22 00:33:01 2018, páginas 490
# El Mon Oct 22 00:33:05 2018, páginas 491
# El Mon Oct 22 00:33:08 2018, páginas 492
# El Mon Oct 22 00:33:12 2018, páginas 493
# El Mon Oct 22 00:33:15 2018, páginas 494
# El Mon Oct 22 00:33:18 2018, páginas 495
# El Mon Oct 22 00:33:20 2018, páginas 496
# El Mon Oct 22 00:33:24 2018, páginas 497
# El Mon Oct 22 00:33:26 2018, páginas 498
# El Mon Oct 22 00:33:29 2018, páginas 499
# El Mon Oct 22 00:33:31 2018, páginas 500
# El Mon Oct 22 00:33:34 2018, páginas 501
# El Mon Oct 22 00:33:37 2018, páginas 502
# El Mon Oct 22 00:33:41 2018, páginas 503
# El Mon Oct 22 00:33:44 2018, páginas 504
# El Mon Oct 22 00:33:46 2018, páginas 505
# El Mon Oct 22 00:33:49 2018, páginas 506
# El Mon Oct 22 00:33:52 2018, páginas 507
# El Mon Oct 22 00:33:56 2018, páginas 508
# El Mon Oct 22 00:33:59 2018, páginas 509
# El Mon Oct 22 00:34:03 2018, páginas 510
# El Mon Oct 22 00:34:07 2018, páginas 511
# El Mon Oct 22 00:34:11 2018, páginas 512
# El Mon Oct 22 00:34:15 2018, páginas 513
# El Mon Oct 22 00:34:18 2018, páginas 514
# El Mon Oct 22 00:34:22 2018, páginas 515
# El Mon Oct 22 00:34:25 2018, páginas 516
# El Mon Oct 22 00:34:29 2018, páginas 517
# El Mon Oct 22 00:34:32 2018, páginas 518
# El Mon Oct 22 00:34:37 2018, páginas 519
# El Mon Oct 22 00:34:40 2018, páginas 520
# El Mon Oct 22 00:34:44 2018, páginas 521
# El Mon Oct 22 00:34:47 2018, páginas 522
# El Mon Oct 22 00:34:52 2018, páginas 523
# El Mon Oct 22 00:34:56 2018, páginas 524
# El Mon Oct 22 00:34:58 2018, páginas 525
# El Mon Oct 22 00:35:02 2018, páginas 526
# El Mon Oct 22 00:35:05 2018, páginas 527
# El Mon Oct 22 00:35:09 2018, páginas 528
# El Mon Oct 22 00:35:11 2018, páginas 529
# El Mon Oct 22 00:35:16 2018, páginas 530
# El Mon Oct 22 00:35:19 2018, páginas 531
# El Mon Oct 22 00:35:23 2018, páginas 532
# El Mon Oct 22 00:35:27 2018, páginas 533
# El Mon Oct 22 00:35:30 2018, páginas 534
# El Mon Oct 22 00:35:33 2018, páginas 535
# El Mon Oct 22 00:35:37 2018, páginas 536
# El Mon Oct 22 00:35:41 2018, páginas 537
# El Mon Oct 22 00:35:44 2018, páginas 538
# El Mon Oct 22 00:35:48 2018, páginas 539
# El Mon Oct 22 00:35:51 2018, páginas 540
# El Mon Oct 22 00:35:54 2018, páginas 541
# El Mon Oct 22 00:35:58 2018, páginas 542
# El Mon Oct 22 00:36:02 2018, páginas 543
# El Mon Oct 22 00:36:06 2018, páginas 544
# El Mon Oct 22 00:36:10 2018, páginas 545
# El Mon Oct 22 00:36:14 2018, páginas 546
# El Mon Oct 22 00:36:18 2018, páginas 547
# El Mon Oct 22 00:36:22 2018, páginas 548
# El Mon Oct 22 00:36:25 2018, páginas 549
# El Mon Oct 22 00:36:29 2018, páginas 550
# El Mon Oct 22 00:36:33 2018, páginas 551
# El Mon Oct 22 00:36:37 2018, páginas 552
# El Mon Oct 22 00:36:41 2018, páginas 553
# El Mon Oct 22 00:36:44 2018, páginas 554
# El Mon Oct 22 00:36:48 2018, páginas 555
# El Mon Oct 22 00:36:51 2018, páginas 556
# El Mon Oct 22 00:36:55 2018, páginas 557
# El Mon Oct 22 00:36:59 2018, páginas 558
# El Mon Oct 22 00:37:03 2018, páginas 559
# El Mon Oct 22 00:37:07 2018, páginas 560
# El Mon Oct 22 00:37:11 2018, páginas 561
# El Mon Oct 22 00:37:14 2018, páginas 562
# El Mon Oct 22 00:37:18 2018, páginas 563
# El Mon Oct 22 00:37:22 2018, páginas 564
# El Mon Oct 22 00:37:27 2018, páginas 565
# El Mon Oct 22 00:37:30 2018, páginas 566
# El Mon Oct 22 00:37:34 2018, páginas 567
# El Mon Oct 22 00:37:38 2018, páginas 568
# El Mon Oct 22 00:37:41 2018, páginas 569
# El Mon Oct 22 00:37:45 2018, páginas 570
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-36e56227957d> in <module>()
#       7     link = '{}?pagina={}'.format(url, page)
#       8     cookies = response.cookies
# ----> 9     response_iterative = requests.request("GET", link, cookies=cookies)
#      10     paginas.append(response_iterative.text)
#      11     with open("proyectos_congreso.p", "wb") as fp:
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %% [markdown]
# #### Abro la base guardada en un pickle

# %%
 with open("../data_estatica/proye", "rb") as fp:
                 proyectos_ley = pickle.load(fp)

# %% [markdown]
# #### Guardo todos los links a los proyectos

# %%
links = []
for page in proyectos_ley[:2]:
    for link in BeautifulSoup(page, 'html5lib').find_all('a', class_ = 'btn btn-info'):
        links.append(link.get('href'))

# %% [markdown]
# ### Armo la base de proyecto con expediente, camara iniciadora y título

# %%
metadata_proyecto = []

for page in tqdm(proyectos_ley):
    soup = BeautifulSoup(page, 'html5lib')
    soup_proyectos = soup.find_all('div', class_ = 'detalle-proyecto')
    for soup_proyecto in soup_proyectos:
        metadata = soup_proyecto.find_all('div', class_ = 'dp-metadata')
        titulos = soup_proyecto.find_all('div', class_ = 'dp-texto')
        for metadatos, titulo in zip(metadata, titulos):
            spans = metadatos.find_all('span')
            try:
                exp_num = re.search('[0-9]+[-]+[D-S]+[-][0-9]+', str(spans)).group(0)
            except:
                pass
            for span in spans:
                dato = span.get_text().split(':')
                dato.append(titulo.get_text())
                dato.append(exp_num)
                metadata_proyecto.append(dato)
# Out:
# 100%|██████████| 2003/2003 [06:30<00:00,  5.13it/s]

# %%
proyectos_expediente = pd.DataFrame(metadata_proyecto)

# %%
del metadata_proyecto

# %%
proyectos_expediente.columns = ['metadata', 'valores', 'titulo', 'expediente']

# %%
proyectos_expediente_table = proyectos_expediente.\
pivot_table(index = ['expediente', 'titulo'], columns = 'metadata', values= 'valores', aggfunc = 'first').\
reset_index()

# %%
proyectos_expediente_table.head()
# Out:
# metadata   expediente                                             titulo  \
# 0         0001-D-2008  CODIGO CIVIL: MODIFICACION DEL INCISO E) DEL A...
# 1         0001-D-2010  REGIMEN DE CREACION DE COMISIONES INVESTIGADOR...
# 2         0001-D-2011  CONSEJO DE LA MAGISTRATURA (LEY 24937): MODIFI...
# 3         0001-S-2008  MODIFICACION DEL ARTICULO 938 DEL CODIGO CIVIL...
# 4         0001-S-2009        CREACION DEL CONSEJO CONSULTIVO DEL TABACO.
#
# metadata Expediente Diputados Expediente Senado        Fecha Iniciado en  \
# 0                 0001-D-2008               NaN   03/03/2008   Diputados
# 1                 0001-D-2010               NaN   02/03/2010   Diputados
# 2                 0001-D-2011               NaN   01/03/2011   Diputados
# 3                         NaN       0001-S-2008   03/03/2008      Senado
# 4                         NaN       0001-S-2009   02/03/2009      Senado
#
# metadata                      Publicado en
# 0               Trámite Parlamentario N° 1
# 1               Trámite Parlamentario N° 3
# 2               Trámite Parlamentario N° 1
# 3          Diario de Asuntos Entrados N° 1
# 4          Diario de Asuntos Entrados N° 1

# %%
#proyectos_expediente_table.to_csv('proyectos_ley_expedientes.csv', index = False)

# %% [markdown]
# ### Armo la base de giros en Diputados

# %%
data = []

for page in tqdm(proyectos_ley):
    soup = BeautifulSoup(page, 'html5lib')
    soup_proyectos = soup.find_all('div', class_ = 'detalle-proyecto')
    for proyecto in soup_proyectos:
        table_body = proyecto.find('table', class_ = 'dp-giros-diputados table table-condensed table-striped')
        titulo = proyecto.find('div', class_ = 'dp-texto')
        metadata = proyecto.find_all('div', class_ = 'dp-metadata')
        try:
            exp_num = re.search('[0-9]+[-]+[D-S]+[-][0-9]+', str(metadata)).group(0)
        except:
            pass           
        if table_body:
            rows = table_body.find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.replace('\xa0', ' ').strip() for ele in cols]
                if cols:
                    cols.insert(0, titulo.get_text())
                    cols.insert(0, exp_num)
                data.append([ele for ele in cols if ele])
# Out:
# 100%|██████████| 2003/2003 [06:35<00:00,  5.06it/s]

# %%
giros_diputados = pd.DataFrame([x for x in data if x])
giros_diputados.columns = ['expediente', 'titulo', 'giro_a_comision']

# %%
giros_diputados.tail()
# Out:
#         expediente                                             titulo  \
# 60757  2377-D-2006  INSTITUCION DE LA "FIESTA DE LA FAMILIA", CONO...
# 60758  2376-D-2006  INSTITUCION DE LA "FIESTA NACIONAL DE LA CARNE...
# 60759  2376-D-2006  INSTITUCION DE LA "FIESTA NACIONAL DE LA CARNE...
# 60760  2360-D-2006  TRANSFERENCIA A TITULO GRATUITO DE UN INMUEBLE...
# 60761  2360-D-2006  TRANSFERENCIA A TITULO GRATUITO DE UN INMUEBLE...
#
#            giro_a_comision
# 60757  LEGISLACION GENERAL
# 60758            INDUSTRIA
# 60759  LEGISLACION GENERAL
# 60760  LEGISLACION GENERAL
# 60761            EDUCACION

# %%
#giros_diputados.to_csv('proyectos_ley_giros_diputados.csv', index = False)

# %% [markdown]
# ### Armo la base de giros en Senado

# %%
data = []

for page in tqdm(proyectos_ley):
    soup = BeautifulSoup(page, 'html5lib')
    soup_proyectos = soup.find_all('div', class_ = 'detalle-proyecto')
    for proyecto in soup_proyectos:
        table_body = proyecto.find('table', class_ = 'dp-giros-senado table table-condensed table-striped')
        titulo = proyecto.find('div', class_ = 'dp-texto')
        metadata = proyecto.find_all('div', class_ = 'dp-metadata')
        try:
            exp_num = re.search('[0-9]+[-]+[D-S]+[-][0-9]+', str(metadata)).group(0)
        except:
            pass           
        if table_body:
            rows = table_body.find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.replace('\xa0', ' ').strip() for ele in cols]
                if cols:
                    cols.insert(0, titulo.get_text())
                    cols.insert(0, exp_num)
                data.append([ele for ele in cols if ele])
# Out:
# 100%|██████████| 2003/2003 [06:46<00:00,  4.93it/s]

# %%
giros_senado = pd.DataFrame([x for x in data if x])
giros_senado.columns = ['expediente', 'titulo', 'giro_a_comision']

# %%
giros_senado.tail()
# Out:
#         expediente                                             titulo  \
# 22888  1453-S-2006  CREACION DEL PROGRAMA DE EDUCACION "FUNDADORES...
# 22889  1452-S-2006               REGIMEN DE MEDIERIA FRUTIHORTICOLA .
# 22890  1452-S-2006               REGIMEN DE MEDIERIA FRUTIHORTICOLA .
# 22891  1451-S-2006  DECLARAR DE INTERES NACIONAL LA FABRICACION DE...
# 22892  1449-S-2006  MODIFICACION DEL CODIGO PENAL INCLUYENDO A FAM...
#
#                       giro_a_comision
# 22888          PRESUPUESTO Y HACIENDA
# 22889             LEGISLACION GENERAL
# 22890  AGRICULTURA, GANADERIA Y PESCA
# 22891            INDUSTRIA Y COMERCIO
# 22892      JUSTICIA Y ASUNTOS PENALES

# %%
#giros_senado.to_csv('proyectos_ley_giros_senado.csv', index = False)

# %% [markdown]
# ### Armo la base de firmantes

# %%
data = []

for page in tqdm(proyectos_ley):
    soup = BeautifulSoup(page, 'html5lib')
    soup_proyectos = soup.find_all('div', class_ = 'detalle-proyecto')
    for proyecto in soup_proyectos:
        table_body = proyecto.find('table', class_ = 'dp-firmantes table table-condensed table-striped')
        titulo = proyecto.find('div', class_ = 'dp-texto')
        metadata = proyecto.find_all('div', class_ = 'dp-metadata')
        try:
            exp_num = re.search('[0-9]+[-]+[D-S]+[-][0-9]+', str(metadata)).group(0)
        except:
            pass           
        if table_body:
            rows = table_body.find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.replace('\xa0', ' ').strip() for ele in cols]
                if cols:
                    cols.insert(0, titulo.get_text())
                    cols.insert(0, exp_num)
                data.append([ele for ele in cols if ele])
# Out:
# 100%|██████████| 2003/2003 [06:33<00:00,  5.08it/s]

# %%
firmantes = pd.DataFrame([x for x in data if x])
firmantes.columns = ['expediente', 'titulo', 'firmante', 'distrito', 'bloque']

# %%
firmantes.tail()
# Out:
#          expediente                                             titulo  \
# 107837  2376-D-2006  INSTITUCION DE LA "FIESTA NACIONAL DE LA CARNE...
# 107838  2376-D-2006  INSTITUCION DE LA "FIESTA NACIONAL DE LA CARNE...
# 107839  2360-D-2006  TRANSFERENCIA A TITULO GRATUITO DE UN INMUEBLE...
# 107840  2360-D-2006  TRANSFERENCIA A TITULO GRATUITO DE UN INMUEBLE...
# 107841  2360-D-2006  TRANSFERENCIA A TITULO GRATUITO DE UN INMUEBLE...
#
#                          firmante      distrito                        bloque
# 107837              BERRAUTE, ANA      SANTA FE  FRENTE PARA LA VICTORIA - PJ
# 107838  NEMIROVSCI, OSVALDO MARIO     RIO NEGRO  FRENTE PARA LA VICTORIA - PJ
# 107839     CHIACCHIO, NORA ALICIA  BUENOS AIRES             PERONISTA FEDERAL
# 107840  VILLAVERDE, JORGE ANTONIO  BUENOS AIRES             PERONISTA FEDERAL
# 107841  NEMIROVSCI, OSVALDO MARIO     RIO NEGRO  FRENTE PARA LA VICTORIA - PJ

# %%
#firmantes.to_csv('proyectos_ley_firmantes.csv', index = False)

# %% [markdown]
# ### Armo la base de trámites

# %%
data = []

for page in tqdm(proyectos_ley):
    soup = BeautifulSoup(page, 'html5lib')
    soup_proyectos = soup.find_all('div', class_ = 'detalle-proyecto')
    for proyecto in soup_proyectos:
        table_body = proyecto.find('table', class_ = 'dp-tramites table table-condensed table-striped')
        titulo = proyecto.find('div', class_ = 'dp-texto')
        metadata = proyecto.find_all('div', class_ = 'dp-metadata')
        try:
            exp_num = re.search('[0-9]+[-]+[D-S]+[-][0-9]+', str(metadata)).group(0)
        except:
            pass           
        if table_body:
            rows = table_body.find_all('tr')
            for row in rows:
                cols = row.find_all('td')
                cols = [ele.text.replace('\xa0', ' ').strip() for ele in cols]
                if cols:
                    cols.insert(0, titulo.get_text())
                    cols.insert(0, exp_num)
                data.append([ele for ele in cols if ele])
# Out:
# 100%|██████████| 2003/2003 [06:42<00:00,  4.97it/s]

# %%
tramites = pd.DataFrame([x for x in data if x])
tramites.columns = ['expediente', 'titulo', 'camara', 'movimiento', 'fecha', 'resultado']

# %%
tramites.tail()
# Out:
#         expediente                                             titulo  \
# 27825  2381-D-2006  AGENCIAS DE VIAJES DE TURISMO, LEY 25599: MODI...
# 27826  2381-D-2006  AGENCIAS DE VIAJES DE TURISMO, LEY 25599: MODI...
# 27827  2381-D-2006  AGENCIAS DE VIAJES DE TURISMO, LEY 25599: MODI...
# 27828  2381-D-2006  AGENCIAS DE VIAJES DE TURISMO, LEY 25599: MODI...
# 27829  2381-D-2006  AGENCIAS DE VIAJES DE TURISMO, LEY 25599: MODI...
#
#           camara                                         movimiento  \
# 27825  Diputados  SOLICITUD DE SER COFIRMANTES DE LOS DIPUTADOS ...
# 27826  Diputados  MOCION SOBRE TABLAS (AFIRMATIVA) CONJUNTAMENTE...
# 27827  Diputados  CONSIDERACION Y APROBACION EN GENERAL (VOTACIO...
# 27828  Diputados  CONSIDERACION Y APROBACION CON MODIFICACIONES ...
# 27829     Senado  PASA A SENADO -  CONJUNTAMENTE PARA LOS EXPEDI...
#
#             fecha      resultado
# 27825        None           None
# 27826  05/07/2006           None
# 27827  05/07/2006           None
# 27828  05/07/2006  MEDIA SANCION
# 27829        None           None

# %%
#tramites.to_csv('proyectos_ley_tramites.csv', index = False)
